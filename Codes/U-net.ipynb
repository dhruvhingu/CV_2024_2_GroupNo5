# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
import random
import cv2
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input, Dropout
from tensorflow.keras.models import Model

plt.rcParams['figure.figsize'] = (20,8)
plt.rcParams['font.size'] = 16

# %%
base_directory = '/kaggle/input/cv-road-marking/Dataset_cv/augmented_dataset'
images_folder = os.path.join(base_directory, 'images/train')
masks_folder = os.path.join(base_directory, 'masks/train')

# %%
img_dim = 256

image_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.15)
mask_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.15)

train_image_generator = image_datagen.flow_from_directory(
        '/kaggle/input/cv-road-marking/Dataset_cv/augmented_dataset/images',
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train'],
        batch_size = 32,
        seed=42,
        subset='training')
    
train_mask_generator = mask_datagen.flow_from_directory(
        '/kaggle/input/cv-road-marking/Dataset_cv/augmented_dataset/masks',
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train'],
        color_mode = 'grayscale',
        batch_size = 32,
        seed=42,
        subset='training')

val_image_generator = image_datagen.flow_from_directory(
        '/kaggle/input/cv-road-marking/Dataset_cv/augmented_dataset/images',
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train'],
        batch_size = 32,
        seed=42,
        subset='validation')
    
val_mask_generator = mask_datagen.flow_from_directory(
        '/kaggle/input/cv-road-marking/Dataset_cv/augmented_dataset/masks',
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train'],
        color_mode = 'grayscale',
        batch_size = 32,
        seed=42,
        subset='validation')

train_generator = zip(train_image_generator, train_mask_generator)
val_generator = zip(val_image_generator, val_mask_generator)
# Out:
# Found 1273 images belonging to 1 classes.
# Found 1273 images belonging to 1 classes.
# Found 224 images belonging to 1 classes.
# Found 224 images belonging to 1 classes.

# %%
training_samples_size = train_image_generator.samples
val_samples_size = val_image_generator.samples

# %%
n = 0
for i,m in train_generator:
    img,mask = i,m

    if n < 5:
        fig, axs = plt.subplots(1 , 2, figsize=(20,4))
        axs[0].imshow(img[0])
        axs[0].set_title('Input Image')
        axs[1].imshow(mask[0],cmap='gray')
        axs[1].set_title('Mask Image')
        plt.show()
        n+=1
    else:
        break

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    b1 = conv_block(p4, 512)

    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
from keras import backend as K

def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

def iou_coef_loss(y_true, y_pred):
    return -iou_coef(y_true, y_pred)

def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = label(y_true_in > 0.5)
    y_pred = label(y_pred_in > 0.5)
    
    true_objects = len(np.unique(labels))
    pred_objects = len(np.unique(y_pred))

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.array(np.mean(metric), dtype=np.float32)

def my_iou_metric(label, pred):
    metric_value = tf.compat.v1.py_func(iou_metric_batch, [label, pred], tf.float32)
    return metric_value

# %%
input_shape = (img_dim, img_dim, 3)
model = build_unet(input_shape)
model.compile(optimizer = tf.keras.optimizers.Adam(lr = 0.001), loss = ['binary_crossentropy'], metrics=[iou_coef,'accuracy'])
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 32) 9248        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 512)  2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 512)  2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 256)  524544      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 512)  0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 128)  131200      activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 64) 32832       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 64) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 32) 8224        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256, 256, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 32) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  33          activation_17[0][0]
# ==================================================================================================
# Total params: 7,771,873
# Trainable params: 7,765,985
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
model_path = "unet.h5"
checkpoint = ModelCheckpoint(model_path,
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)

# %%
history = model.fit(train_generator,
                    steps_per_epoch=training_samples_size//32,
                    validation_data=val_generator,
                    validation_steps=val_samples_size//32,
                    epochs=50)
# Out:
# Epoch 1/50
# 39/39 [==============================] - 27s 701ms/step - loss: 0.1131 - iou_coef: 0.3485 - accuracy: 0.9333 - val_loss: 0.2540 - val_iou_coef: 0.1139 - val_accuracy: 0.8946
# Epoch 2/50
# 39/39 [==============================] - 26s 677ms/step - loss: 0.1026 - iou_coef: 0.3629 - accuracy: 0.9352 - val_loss: 0.2233 - val_iou_coef: 0.1056 - val_accuracy: 0.8905
# Epoch 3/50
# 39/39 [==============================] - 27s 702ms/step - loss: 0.0975 - iou_coef: 0.3956 - accuracy: 0.9360 - val_loss: 0.2186 - val_iou_coef: 0.2030 - val_accuracy: 0.8923
# Epoch 4/50
# 39/39 [==============================] - 26s 688ms/step - loss: 0.0942 - iou_coef: 0.3978 - accuracy: 0.9363 - val_loss: 0.1672 - val_iou_coef: 0.2399 - val_accuracy: 0.9134
# Epoch 5/50
# 39/39 [==============================] - 27s 698ms/step - loss: 0.0871 - iou_coef: 0.4142 - accuracy: 0.9370 - val_loss: 0.2513 - val_iou_coef: 0.1407 - val_accuracy: 0.8967
# Epoch 6/50
# 39/39 [==============================] - 27s 691ms/step - loss: 0.0883 - iou_coef: 0.4182 - accuracy: 0.9367 - val_loss: 0.2753 - val_iou_coef: 0.1988 - val_accuracy: 0.8852
# Epoch 7/50
# 39/39 [==============================] - 27s 697ms/step - loss: 0.0820 - iou_coef: 0.4289 - accuracy: 0.9382 - val_loss: 0.2600 - val_iou_coef: 0.1300 - val_accuracy: 0.8961
# Epoch 8/50
# 39/39 [==============================] - 26s 688ms/step - loss: 0.0902 - iou_coef: 0.4112 - accuracy: 0.9344 - val_loss: 0.1538 - val_iou_coef: 0.3110 - val_accuracy: 0.9197
# Epoch 9/50
# 39/39 [==============================] - 27s 698ms/step - loss: 0.0779 - iou_coef: 0.4514 - accuracy: 0.9391 - val_loss: 0.1082 - val_iou_coef: 0.3583 - val_accuracy: 0.9273
# Epoch 10/50
# 39/39 [==============================] - 27s 696ms/step - loss: 0.0744 - iou_coef: 0.4528 - accuracy: 0.9393 - val_loss: 0.1224 - val_iou_coef: 0.3116 - val_accuracy: 0.9239
# Epoch 11/50
# 39/39 [==============================] - 26s 685ms/step - loss: 0.0763 - iou_coef: 0.4565 - accuracy: 0.9380 - val_loss: 0.1398 - val_iou_coef: 0.3023 - val_accuracy: 0.9211
# Epoch 12/50
# 39/39 [==============================] - 27s 692ms/step - loss: 0.0739 - iou_coef: 0.4599 - accuracy: 0.9379 - val_loss: 0.1364 - val_iou_coef: 0.3126 - val_accuracy: 0.9185
# Epoch 13/50
# 39/39 [==============================] - 26s 686ms/step - loss: 0.0701 - iou_coef: 0.4673 - accuracy: 0.9395 - val_loss: 0.1056 - val_iou_coef: 0.3554 - val_accuracy: 0.9250
# Epoch 14/50
# 39/39 [==============================] - 27s 702ms/step - loss: 0.0666 - iou_coef: 0.5011 - accuracy: 0.9397 - val_loss: 0.1572 - val_iou_coef: 0.2984 - val_accuracy: 0.9150
# Epoch 15/50
# 39/39 [==============================] - 28s 716ms/step - loss: 0.0652 - iou_coef: 0.4810 - accuracy: 0.9390 - val_loss: 0.1234 - val_iou_coef: 0.3167 - val_accuracy: 0.9252
# Epoch 16/50
# 39/39 [==============================] - 27s 713ms/step - loss: 0.0605 - iou_coef: 0.5085 - accuracy: 0.9422 - val_loss: 0.1127 - val_iou_coef: 0.3920 - val_accuracy: 0.9250
# Epoch 17/50
# 39/39 [==============================] - 27s 700ms/step - loss: 0.0604 - iou_coef: 0.5125 - accuracy: 0.9405 - val_loss: 0.0857 - val_iou_coef: 0.4496 - val_accuracy: 0.9317
# Epoch 18/50
# 39/39 [==============================] - 27s 699ms/step - loss: 0.0729 - iou_coef: 0.4736 - accuracy: 0.9381 - val_loss: 0.1777 - val_iou_coef: 0.2655 - val_accuracy: 0.9176
# Epoch 19/50
# 39/39 [==============================] - 26s 686ms/step - loss: 0.0631 - iou_coef: 0.5023 - accuracy: 0.9402 - val_loss: 0.1190 - val_iou_coef: 0.3792 - val_accuracy: 0.9238
# Epoch 20/50
# 39/39 [==============================] - 26s 683ms/step - loss: 0.0590 - iou_coef: 0.5167 - accuracy: 0.9415 - val_loss: 0.0845 - val_iou_coef: 0.4137 - val_accuracy: 0.9301
# Epoch 21/50
# 39/39 [==============================] - 27s 695ms/step - loss: 0.0580 - iou_coef: 0.5219 - accuracy: 0.9403 - val_loss: 0.0795 - val_iou_coef: 0.4522 - val_accuracy: 0.9342
# Epoch 22/50
# 39/39 [==============================] - 26s 681ms/step - loss: 0.0537 - iou_coef: 0.5316 - accuracy: 0.9429 - val_loss: 0.0815 - val_iou_coef: 0.4604 - val_accuracy: 0.9311
# Epoch 23/50
# 39/39 [==============================] - 27s 695ms/step - loss: 0.0545 - iou_coef: 0.5450 - accuracy: 0.9416 - val_loss: 0.0868 - val_iou_coef: 0.4204 - val_accuracy: 0.9308
# Epoch 24/50
# 39/39 [==============================] - 27s 691ms/step - loss: 0.0544 - iou_coef: 0.5268 - accuracy: 0.9415 - val_loss: 0.0799 - val_iou_coef: 0.4431 - val_accuracy: 0.9344
# Epoch 25/50
# 39/39 [==============================] - 27s 695ms/step - loss: 0.0530 - iou_coef: 0.5447 - accuracy: 0.9418 - val_loss: 0.1063 - val_iou_coef: 0.4344 - val_accuracy: 0.9275
# Epoch 26/50
# 39/39 [==============================] - 26s 685ms/step - loss: 0.0527 - iou_coef: 0.5467 - accuracy: 0.9424 - val_loss: 0.0858 - val_iou_coef: 0.4500 - val_accuracy: 0.9313
# Epoch 27/50
# 39/39 [==============================] - 27s 700ms/step - loss: 0.0529 - iou_coef: 0.5422 - accuracy: 0.9417 - val_loss: 0.0863 - val_iou_coef: 0.4243 - val_accuracy: 0.9330
# Epoch 28/50
# 39/39 [==============================] - 27s 702ms/step - loss: 0.0500 - iou_coef: 0.5498 - accuracy: 0.9427 - val_loss: 0.1297 - val_iou_coef: 0.3936 - val_accuracy: 0.9223
# Epoch 29/50
# 39/39 [==============================] - 27s 695ms/step - loss: 0.0619 - iou_coef: 0.5159 - accuracy: 0.9390 - val_loss: 0.3544 - val_iou_coef: 0.3093 - val_accuracy: 0.8991
# Epoch 30/50
# 39/39 [==============================] - 27s 693ms/step - loss: 0.0625 - iou_coef: 0.5071 - accuracy: 0.9396 - val_loss: 0.4035 - val_iou_coef: 0.1138 - val_accuracy: 0.8904
# Epoch 31/50
# 39/39 [==============================] - 26s 683ms/step - loss: 0.0530 - iou_coef: 0.5426 - accuracy: 0.9424 - val_loss: 0.0978 - val_iou_coef: 0.3911 - val_accuracy: 0.9287
# Epoch 32/50
# 39/39 [==============================] - 27s 700ms/step - loss: 0.0507 - iou_coef: 0.5546 - accuracy: 0.9424 - val_loss: 0.0856 - val_iou_coef: 0.4372 - val_accuracy: 0.9300
# Epoch 33/50
# 39/39 [==============================] - 26s 683ms/step - loss: 0.0488 - iou_coef: 0.5628 - accuracy: 0.9426 - val_loss: 0.0818 - val_iou_coef: 0.4612 - val_accuracy: 0.9321
# Epoch 34/50
# 39/39 [==============================] - 27s 701ms/step - loss: 0.0481 - iou_coef: 0.5618 - accuracy: 0.9426 - val_loss: 0.0774 - val_iou_coef: 0.4851 - val_accuracy: 0.9344
# Epoch 35/50
# 39/39 [==============================] - 27s 697ms/step - loss: 0.0478 - iou_coef: 0.5674 - accuracy: 0.9423 - val_loss: 0.0801 - val_iou_coef: 0.4468 - val_accuracy: 0.9314
# Epoch 36/50
# 39/39 [==============================] - 26s 688ms/step - loss: 0.0467 - iou_coef: 0.5733 - accuracy: 0.9432 - val_loss: 0.0784 - val_iou_coef: 0.4913 - val_accuracy: 0.9339
# Epoch 37/50
# 39/39 [==============================] - 26s 683ms/step - loss: 0.0468 - iou_coef: 0.5688 - accuracy: 0.9428 - val_loss: 0.0876 - val_iou_coef: 0.4702 - val_accuracy: 0.9326
# Epoch 38/50
# 39/39 [==============================] - 26s 677ms/step - loss: 0.0464 - iou_coef: 0.5767 - accuracy: 0.9431 - val_loss: 0.0789 - val_iou_coef: 0.4893 - val_accuracy: 0.9348
# Epoch 39/50
# 39/39 [==============================] - 26s 686ms/step - loss: 0.0459 - iou_coef: 0.5787 - accuracy: 0.9439 - val_loss: 0.1486 - val_iou_coef: 0.4422 - val_accuracy: 0.9214
# Epoch 40/50
# 39/39 [==============================] - 26s 684ms/step - loss: 0.0500 - iou_coef: 0.5533 - accuracy: 0.9420 - val_loss: 0.1103 - val_iou_coef: 0.4481 - val_accuracy: 0.9287
# Epoch 41/50
# 39/39 [==============================] - 27s 698ms/step - loss: 0.0470 - iou_coef: 0.5753 - accuracy: 0.9424 - val_loss: 0.0898 - val_iou_coef: 0.4585 - val_accuracy: 0.9303
# Epoch 42/50
# 39/39 [==============================] - 26s 684ms/step - loss: 0.0442 - iou_coef: 0.5760 - accuracy: 0.9438 - val_loss: 0.0894 - val_iou_coef: 0.4745 - val_accuracy: 0.9301
# Epoch 43/50
# 39/39 [==============================] - 27s 691ms/step - loss: 0.0451 - iou_coef: 0.5846 - accuracy: 0.9422 - val_loss: 0.0837 - val_iou_coef: 0.4954 - val_accuracy: 0.9324
# Epoch 44/50
# 39/39 [==============================] - 26s 683ms/step - loss: 0.0435 - iou_coef: 0.5839 - accuracy: 0.9444 - val_loss: 0.0889 - val_iou_coef: 0.4804 - val_accuracy: 0.9303
# Epoch 45/50
# 39/39 [==============================] - 26s 677ms/step - loss: 0.0438 - iou_coef: 0.5916 - accuracy: 0.9442 - val_loss: 0.0919 - val_iou_coef: 0.4932 - val_accuracy: 0.9301
# Epoch 46/50
# 39/39 [==============================] - 27s 702ms/step - loss: 0.0440 - iou_coef: 0.5841 - accuracy: 0.9433 - val_loss: 0.0867 - val_iou_coef: 0.4856 - val_accuracy: 0.9313
# Epoch 47/50
# 39/39 [==============================] - 26s 683ms/step - loss: 0.0434 - iou_coef: 0.5925 - accuracy: 0.9438 - val_loss: 0.0997 - val_iou_coef: 0.4714 - val_accuracy: 0.9307
# Epoch 48/50
# 39/39 [==============================] - 27s 696ms/step - loss: 0.0433 - iou_coef: 0.5842 - accuracy: 0.9437 - val_loss: 0.0884 - val_iou_coef: 0.4723 - val_accuracy: 0.9302
# Epoch 49/50
# 39/39 [==============================] - 26s 686ms/step - loss: 0.0435 - iou_coef: 0.5872 - accuracy: 0.9424 - val_loss: 0.0954 - val_iou_coef: 0.5245 - val_accuracy: 0.9363
# Epoch 50/50
# 39/39 [==============================] - 27s 695ms/step - loss: 0.0420 - iou_coef: 0.5994 - accuracy: 0.9444 - val_loss: 0.0944 - val_iou_coef: 0.4940 - val_accuracy: 0.9310

# %%
import seaborn as sns
sns.set_style('dark')

# %% [markdown]
# ## Learning Curve

# %%
plt.figure(figsize=(20,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.ylim([0,2])
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
random_val_samples = val_generator.__next__()
val_image_samples = random_val_samples[0]
val_mask_samples = random_val_samples[1]
predicted_masks = model.predict(val_image_samples)

predicted_masks[predicted_masks >= 0.2] = 1
predicted_masks[predicted_masks < 0.2] = 0

# %% [markdown]
# ## Ground Truth Masks vs Predicted Masks

# %%
f, axarr = plt.subplots(15,3,figsize=(20, 60))

for i in range(0,15):

    axarr[i,0].imshow(val_image_samples[i])
    axarr[i,0].title.set_text('Original Image')
    axarr[i,0].axis('off')
    axarr[i,1].imshow(val_mask_samples[i])
    axarr[i,1].title.set_text('Actual Mask')
    axarr[i,1].axis('off')
    axarr[i,2].imshow(predicted_masks[i])
    axarr[i,2].title.set_text('Predicted Mask')
    axarr[i,2].axis('off')

# %% [markdown]
# # Conclusion
# - In some cases the segmented masks do not match with the ground truth mask. The reason behind this is that some of the images were not properly labelled during the data preparation.
# - Therefore our model is able to identify certain features that help us segment the forest areas which are not labelled in ground truth images.
# - However, the overall performance of our model can be improved by using different metrics relevant to image segmentation
